# %% [markdown]
# # Reading the Data

# %%
import pandas as pd
df=pd.read_csv("/content/Mall_Customers.csv")
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# # Data Analysis & Data Visualization

# %%
df.shape #'.shape' returns a tuple
# Out:
# (200, 5)

# %% [markdown]
# There are **200 rows & 5 columns**. This means **200 data points** in the data and **5 features**.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# All the features are integer except the feature **'Gender'**. All the data are **non-null**. Which is good for us.

# %% [markdown]
# Now let's see what kind of trends are there in the Dataset. We will first start with looking at how many males and females are there in the dataset

# %%
import seaborn as sns
sns.countplot('Gender',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# From here we can see the number of females is **more than** the number of males. (As Expected!!!). Now let's see how many people belong to different ages.

# %%
sns.countplot('Age',hue='Gender',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# the labels are not clear. So let's zoom in a bit.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,6))
sns.countplot('Age',hue='Gender',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# *   There are two age ranges who comes the most to the mall. 1st age range is 27-38 and the second age range is 47-50.
#
#
# *   For the age group 18,19,20 the number of males is more than the number of females.

# %% [markdown]
# Let's have a similar observation for Annual Income

# %%
f,ax=plt.subplots(figsize=(20,10))
ax=sns.countplot('Annual Income (k$)',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import seaborn as sns
sns.pairplot(df, hue='Gender')

# %% [markdown]
# * pairplot is a such kind of plots whose diagonal plots are histogram type and the off diagonal plots are scatterplot type
#
# *  Here we see that the feature 'Gender' is not much of a differentiating factor means all types of gender(Male & Female) are distributed over the hole curve with out forming any cluster. So we can easily get rid of it by **dropping** it.
#
# *  Secondly, the feature CustomerID is also not going to take me anywhere as that is somewhere abrupt. So we will **drop** that also.

# %%
plt.figure(figsize=(25,16))
sns.pairplot(df, hue='Age')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# * here we see the age 20-40 are pointed in an specific region(50-70 are also present there but very less),age 50-70 are pointed an another specific region(here also 20-40 age customer are present but very less)
#
# * So we can not drop the feature 'Age' as it helps to forming clusters

# %%
df=df.drop(['Gender','CustomerID'],axis=1)

# %%
df
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 0     19                  15                      39
# 1     21                  15                      81
# 2     20                  16                       6
# 3     23                  16                      77
# 4     31                  17                      40
# ..   ...                 ...                     ...
# 195   35                 120                      79
# 196   45                 126                      28
# 197   32                 126                      74
# 198   32                 137                      18
# 199   30                 137                      83
#
# [200 rows x 3 columns]

# %% [markdown]
# * Here we drop the two features'Gender' and 'Customer ID'

# %% [markdown]
# # Building the Model

# %%
from sklearn.cluster import KMeans
clusters=[]
for i in range(1, 11):
    km = KMeans(n_clusters=i).fit(df)
    clusters.append(km.inertia_)
clusters
# Out:
# [308812.78,
#  212840.16982097185,
#  143342.751571706,
#  104374.1598511286,
#  75350.77917248776,
#  58300.44332159069,
#  51120.80202614004,
#  44312.46881207721,
#  40592.69511893991,
#  37555.27242540346]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))

sns.lineplot(x=list(range(1, 11)), y=clusters)

# %% [markdown]
# * Since we can see two elbows here at 3 and 5 so the best clusters should be one of them. So we will make 3 clusters and 5 clusters and check which one is giving good insight of the model.

# %% [markdown]
# Making 3 clusters

# %%
km3 = KMeans(n_clusters=3).fit(df)

df['Labels'] = km3.labels_
plt.figure(figsize=(12, 8))
sns.scatterplot(df['Annual Income (k$)'], df['Spending Score (1-100)'], hue=df['Labels'], 
                palette=sns.color_palette('hls', 3))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * Here the clusters are not distributed in a good manner as maximum data point belongs in the cluster no 1 and also its range is more than the others two

# %% [markdown]
# Making 5 clusters

# %%
km5 = KMeans(n_clusters=5).fit(df)

df['Labels'] = km5.labels_
plt.figure(figsize=(12, 8))
sns.scatterplot(df['Annual Income (k$)'], df['Spending Score (1-100)'], hue=df['Labels'], palette=sns.color_palette('hls', 5))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# here the distribution is better than the previous one
